# %% [markdown]
# # Import libraries

# %%
import sys
from pathlib import Path
sys.path.insert(0,'..')
import glob
#!pip install openpyxl

# %%
import os
import sys
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import h5py
import re

from functools import partial
from multiprocessing import Pool

from lhcsmapi.Time import Time
from lhcsmapi.Timer import Timer
from lhcsmapi.metadata.MappingMetadata import MappingMetadata
from scipy import signal
import xarray as xr

from src.utils.utils import log_acquisition
from src.utils.hdf_tools import acquisition_to_hdf5, load_from_hdf_with_regex
from src.visualisation.sec_quench_visualisation import plot_wiggle_analysis
from src.modeling.sec_quench import *
from src.utils.dataset_utils import *
from src.utils.utils import interp

import numpy as np
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import decomposition
from scipy.interpolate import interp2d
from scipy.signal import find_peaks, peak_prominences, peak_widths

from src.models import nmf_missing
from src.dataset import load_dataset
from src.datasets.rb_fpa_prim_quench_ee_plateau import RBFPAPrimQuenchEEPlateau
from src.datasets.rb_fpa_prim_quench_ee_plateau2 import RBFPAPrimQuenchEEPlateau2
from src.datasets.rb_fpa_full_quench import RBFPAFullQuench

pd.set_option('display.max_rows', 200)
import warnings
warnings.filterwarnings('ignore')
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_100_nxcals/x86_64-centos7-gcc9-opt/lib/python3.8/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /cvmfs/sft.cern.ch/lcg/views/LCG_100_nxcals/x86_64-centos7-gcc9-opt/lib/python3.8/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %% [markdown]
# # Define Paths

# %%
file_path  = Path('/eos/project/m/ml-for-alarm-system/private/RB_signals')
data_path = file_path / 'backup/20220707_data'
simulation_path = file_path / 'backup/20220707_simulation'

# %% [markdown]
# # Read the (clean) MP3 file

# %%
mp3_fpa_df = pd.read_csv("../data/RB_TC_extract_2022_07_07_processed_filled.csv")
len(mp3_fpa_df)
# Out:
# 3981

# %% [markdown]
# # Read metadata

# %%
metadata_path = Path("../data/RB_metadata.csv")
rb_magnet_metadata = pd.read_csv(metadata_path, index_col=False)
rb_magnet_metadata
# Out:
#      Circuit    Magnet    Position B1_aperture Diode_type Correctors EE place  \
# 0     RB.A12   MB.A8R1    276.7340         EXT          R          A     EVEN
# 1     RB.A12   MB.B8R1    292.3940         EXT          R          B      ODD
# 2     RB.A12   MB.A9R1    315.7990         EXT          R          A     EVEN
# 3     RB.A12   MB.B9R1    331.4590         EXT          R          B      ODD
# 4     RB.A12  MB.A10R1    356.2640         EXT          R          A     EVEN
# ...      ...       ...         ...         ...        ...        ...      ...
# 1227  RB.A81  MB.A10L1  26302.6192         INT          L          B      ODD
# 1228  RB.A81   MB.B9L1  26327.4242         INT          L          A     EVEN
# 1229  RB.A81   MB.A9L1  26343.0842         INT          L          B      ODD
# 1230  RB.A81   MB.B8L1  26366.4892         INT          L          A     EVEN
# 1231  RB.A81   MB.A8L1  26382.1492         INT          L          B      ODD
#
# ...

# %%
rb_magnet_metadata['cryostat_group'] = rb_magnet_metadata['Cryostat2'].apply(lambda x: x.split('_')[1])
last_mpos_in_cryostat = rb_magnet_metadata[rb_magnet_metadata.Circuit=='RB.A12'].groupby("cryostat_group").min().sort_values(by='phys_pos').phys_pos.values

# %% [markdown]
# # FFT Analysis

# %%
from scipy import signal
from scipy.fft import fft, fftfreq, rfft
from matplotlib import colors

def complex_to_polar(x):
    amplitude = np.abs(x)
    phase = np.arctan2(np.imag(x), np.real(x))  # *180/np.pi
    return amplitude, phase

def get_fft_amplitude(x):
    N = len(x)
    
    if np.isnan(x).all():
        y_FFT = fft(np.nan_to_num(x))
        y_FFT = np.zeros_like(y_FFT) * np.nan
    else:
        x = x[~np.isnan(x)]
        x = x * np.hanning(len(x))
        #x = pd.DataFrame(x).rolling(3).median().values.reshape(-1) #salt and peper noise
        y_FFT = fft(np.nan_to_num(x))
    return 2.0 / N * np.abs(y_FFT[0:N // 2])

def get_fft_amplitude_nohanning(x):
    N = len(x)
    
    if np.isnan(x).all():
        y_FFT = fft(np.nan_to_num(x))
        y_FFT = np.zeros_like(y_FFT) * np.nan
    else:
        x = x[~np.isnan(x)]
        #x = pd.DataFrame(x).rolling(3).median().values.reshape(-1) #salt and peper noise
        y_FFT = fft(np.nan_to_num(x))
    return 2.0 / N * np.abs(y_FFT[0:N // 2])

def get_fft_phase(DC_Down_data):
    N = len(DC_Down_data)
    x = fft(DC_Down_data)
    return np.arctan2(np.imag(x), np.real(x))[0:N // 2]


def plot_circuit_frequencies_phys_pos(ax, x_fft, frequency, rb_magnet_metadata_subset):
        
    #phys_pos = rb_magnet_metadata_subset.sort_values(by='#Electric_circuit').phys_pos.values #np.hstack((abs(np.arange(-154,0,2)),np.arange(1,155,2)))
    #phys_pos_sorted = np.argsort(phys_pos)+1
    phys_pos_index = rb_magnet_metadata_subset['#Electric_circuit'].values 
    
    im = ax.imshow(x_fft[phys_pos_index-1].T, extent=[1,154, frequency.min(),frequency.max()], vmin=1e-5, vmax=1e-2, aspect='auto', norm=colors.LogNorm(), origin='lower')
    ax.set_ylabel('Frequency / Hz')
    ax.set_xlabel('Phy. Position')
    ax.set_xticks(np.arange(1,155)[::9])
    
    last_mpos_in_cryostat = rb_magnet_metadata_subset.groupby("cryostat_group").min().sort_values(by='phys_pos').phys_pos.values
    ax.set_xticks(last_mpos_in_cryostat)
    tick_labels = [str(l) if i%3==0 else  '' for i, l in enumerate(last_mpos_in_cryostat)] 
    ax.set_xticklabels(tick_labels)
    
    #plt.title('Frequency Domain')

    #cbar = fig.colorbar(im, ax=ax)
    #cbar.set_label('Voltage')

    plt.tight_layout()
    return im

def plot_circuit_frequencies(ax, x_fft, frequency, rb_magnet_metadata_subset):
    im = ax.imshow(x_fft.T, extent=[1,154, frequency.min(),frequency.max()], vmin=1e-5, vmax=1e-2, aspect='auto', norm=colors.LogNorm(), origin='lower')
    
    ax.set_ylabel('Frequency / Hz')
    ax.set_xlabel('El. Position')
    ax.set_xticks(np.arange(1,155)[::9])

    plt.tight_layout()
    return im

# %%
dataset_path = Path("/eos/project/m/ml-for-alarm-system/private/RB_signals/backup/20220707_prim_ee_plateau_dataset")
plot_dataset_path = Path("/eos/project/m/ml-for-alarm-system/private/RB_signals/FFT_analysis/1EE_plateau_test")
#dataset_path = Path("/eos/project/m/ml-for-alarm-system/private/RB_signals/backup/20220707_RBFPAPrimQuenchEEPlateau2")
#plot_dataset_path = Path("/eos/project/m/ml-for-alarm-system/private/RB_signals/FFT_analysis/2EE_plateau")
plot_dataset_path.mkdir(parents=True, exist_ok=True)

context_path = Path("../data/RB_TC_extract_2022_07_07_processed_filled.csv")
acquisition_summary_path = Path("../data/20220707_acquisition_summary.xlsx")
data_path = Path("/eos/project/m/ml-for-alarm-system/private/RB_signals/backup/20220707_data")
simulation_path = Path("/eos/project/m/ml-for-alarm-system/private/RB_signals/backup/20220707_simulation")
metadata_path = Path("../data/RB_metadata.csv")

# %%
ds = RBFPAPrimQuenchEEPlateau2(dataset_path=dataset_path,
             context_path=context_path,
             metadata_path=metadata_path,
             data_path=data_path,
             simulation_path=simulation_path,
             acquisition_summary_path=acquisition_summary_path,
             plot_dataset_path=plot_dataset_path)

fpa_identifiers = ds.select_events()

dataset = ds.load_dataset(fpa_identifiers=fpa_identifiers, 
                          dataset_path=dataset_path, 
                          drop_data_vars=['el_position_feature','event_feature'])

dataset_scaled = dataset.copy(deep=True)
dataset_scaled = ds.train_valid_test_split(dataset=dataset_scaled)
dataset_scaled = ds.scale_dataset(dataset=dataset_scaled)

# %% [markdown]
# # Signal vs. scaled signal

# %%
fpa_identifier = fpa_identifiers[50]
circuit_name = fpa_identifier.split("_")[1]
timestamp_fgc = int(fpa_identifier.split("_")[2])

mp3_fpa_df_subset = mp3_fpa_df[(mp3_fpa_df.timestamp_fgc == timestamp_fgc) & 
                               (mp3_fpa_df['Circuit Name'] == circuit_name)]

# %%
rb_magnet_metadata_subset = rb_magnet_metadata[rb_magnet_metadata.Circuit==str(fpa_identifier).split('_')[1]]

x_time = dataset.loc[{'event': fpa_identifier}].data
x_fft = np.array([get_fft_amplitude(x) for x in x_time])
dt= dataset[{'event': 0}].time[1].values -dataset[{'event': 0}].time[0].values
frequency = fftfreq(len(x_time[0]), dt)[:len(x_time[0])//2] 

fig, ax = plt.subplots(1, 3, figsize=(20,5))
plt.plot(x_time.T)
ax[0].set_xlabel('Time / s')
ax[0].set_ylabel('Voltage / V')
ax[0].plot(dataset.loc[{'event': fpa_identifier}].time, dataset.loc[{'event': fpa_identifier}].data.T)
ax[0].grid()

plot_circuit_frequencies(ax[1], x_fft, frequency, rb_magnet_metadata_subset)

plot_circuit_frequencies_phys_pos(ax[2], x_fft, frequency, rb_magnet_metadata_subset)
ax[2].grid(linewidth=0.2)

# %% [markdown]
# # Calculate fft of all events

# %%
dataset_fft = xr.apply_ufunc(get_fft_amplitude, 
                             dataset.data,
                             input_core_dims=[['time']], 
                             output_core_dims=[['frequency']], 
                             exclude_dims=set(("time",)),
                             vectorize=True)

# %% [markdown]
# # Center signals

# %%
def extend_to_centered_matrix(matrix, center):
    mask = np.zeros((len(matrix)*2, len(matrix[0]))) * np.nan
    start = len(matrix) - center
    end = start + len(matrix)
    mask[int(start): int(end)] = matrix
    return mask


def preprocess_event(x_fft, frequency, fpa_identifier, max_freq=360):
    max_freq_bool = frequency <= max_freq
    
    x_fft_cut = x_fft[:,max_freq_bool]
    mp3_fpa_df_subset = mp3_fpa_df[(mp3_fpa_df['fpa_identifier'] == fpa_identifier)]
    prim_quench_position = mp3_fpa_df_subset['#Electric_circuit'].values[0]
    x_fft_centered = extend_to_centered_matrix(matrix=x_fft_cut, center=prim_quench_position)

    return x_fft_centered, frequency[max_freq_bool]

def preprocess_event_phys_pos(x_fft, frequency, fpa_identifier, max_freq=360):
    max_freq_bool = frequency <= max_freq
    
    x_fft_cut = x_fft[:,max_freq_bool]
    mp3_fpa_df_subset = mp3_fpa_df[(mp3_fpa_df['fpa_identifier'] == fpa_identifier)]
    prim_quench_position = mp3_fpa_df_subset['phys_position'].values[0]
    x_fft_centered = extend_to_centered_matrix(matrix=x_fft_cut, center=prim_quench_position)

    return x_fft_centered, frequency[max_freq_bool]

# %%
fpa_identifiers = mp3_fpa_df[(mp3_fpa_df['Delta_t(iQPS-PIC)'] / 1000 > 1) & 
                             (mp3_fpa_df['timestamp_fgc'] > 1611836512820000000)
                            ].fpa_identifier.unique()

fpa_identifiers = fpa_identifiers[np.isin(fpa_identifiers, dataset.event.values)]
len(fpa_identifiers)
# Out:
# 542

# %% [markdown]
# # Center signals: mirror el position

# %%
def extend_to_centered_matrix_mirror(matrix, center):
    im_len = int(len(matrix)/2)
    if center > len(matrix) / 2:
        # quench is in second half
        matrix_main = matrix[im_len:]
        matrix_mirror  = matrix[:im_len]
        center_main = center - im_len
        center_mirror = len(matrix) - center
    else:
        # center is in first half
        matrix_main = matrix[:im_len]
        matrix_mirror  = matrix[im_len:]
        center_main = center 
        center_mirror = im_len - center

        
    matrix_main_centered = extend_to_centered_matrix(matrix_main, center_main)
    matrix_mirror_centered = extend_to_centered_matrix(matrix_mirror, center_mirror)
    return matrix_main_centered, matrix_mirror_centered#

def preprocess_event_mirror(x_fft, frequency, fpa_identifier, max_freq=360):
    max_freq_bool = frequency <= max_freq
    
    x_fft_cut = x_fft[:,max_freq_bool]
    mp3_fpa_df_subset = mp3_fpa_df[(mp3_fpa_df['fpa_identifier'] == fpa_identifier)]
    prim_quench_position = mp3_fpa_df_subset['#Electric_circuit'].values[0]
    #print(prim_quench_position)
    x_fft_list = extend_to_centered_matrix_mirror(matrix=x_fft_cut, center=prim_quench_position)

    return x_fft_list, frequency[max_freq_bool]

# %%
def plot_position_frequency_map(ax, x_fft, frequency, norm=colors.LogNorm(), vmin=1e-5, vmax=1e-2):
    im = ax.imshow(x_fft.T, extent=[-77,77, frequency.min(),frequency.max()], vmin=vmin, vmax=vmax, aspect='auto', norm=norm, origin='lower')
    
    ax.set_ylabel('Frequency / Hz')
    ax.set_xlabel('El. Distance to Quench')
    
    plt.tight_layout()
    return im

# %%
x_fft_list, frequency_cut = preprocess_event_mirror(x_fft, frequency, fpa_identifier, max_freq=360)

fig, ax = plt.subplots(figsize=(10,5))
plot_circuit_frequencies(ax, x_fft, frequency_cut, rb_magnet_metadata_subset)

fig, ax = plt.subplots(2,1, figsize=(10,10))
plot_position_frequency_map(ax[0], x_fft_list[0], frequency_cut)
ax[0].set_title('MAIN')
ax[1].set_title('MIRROR')
plot_position_frequency_map(ax[1], x_fft_list[1], frequency_cut)

# %% [markdown]
# # Scale Data

# %%
def log_scale_data(X, vmin=1e-5, vmax=1e-2):
    X_log = np.log10(X)
    vmin_log =np.log10(vmin)
    vmax_log =np.log10(vmax)
    X_std = (X_log - vmin_log) / (vmax_log - vmin_log)
    
    #clip
    X_std[X_std < 0] = 0
    X_std[X_std > 1] = 1
    return X_std

# %% [markdown]
# # Global Statics

# %%
# el pos plot std
x_fft_all = np.zeros((2, len(fpa_identifiers), 154, 116)) #116

for i, fpa_identifier in enumerate(fpa_identifiers): 
    x_fft = dataset_fft.loc[{'event': fpa_identifier}].data
    x_fft_list, frequency_cut = preprocess_event_mirror(x_fft, frequency, fpa_identifier, max_freq=360)
    x_fft_all[0, i] = x_fft_list[0]
    x_fft_all[1, i] = x_fft_list[1]
    
x_fft_3q_main = np.nanquantile(x_fft_all[0], 0.75,  axis=0)
x_fft_3q_mirror = np.nanquantile(x_fft_all[1], 0.75, axis=0)

# %%
v_properties_main, h_properties_main = get_peak_borders(x_fft_3q_main)
v_properties_mirror, h_properties_mirror = get_peak_borders(x_fft_3q_mirror)

fig, ax = plt.subplots(2,1, figsize=(10,10))
plot_position_frequency_map(ax[0], x_fft_3q_main, frequency_cut)
ax[0].set_title('MAIN')

plot_position_frequency_map(ax[1], x_fft_3q_mirror, frequency_cut)
ax[1].set_title('MIRROR')

plt.tight_layout()
plt.show()

# %% [markdown]
# # calc statisticvs

# %%
def get_horizontal_peak_widths(x_fft, peaks, plot=False):
    peak_width_list = []
    df = pd.DataFrame()
    for x in x_fft.T[peaks]:
        nan_bool = np.isnan(x)
        nan_index = np.argmax(nan_bool)
        x[nan_bool] = np.interp(nan_index, np.arange(len(x[~nan_bool])), x[~nan_bool])
        
        peaks, properties = find_peaks(x, prominence=0.2, width=1, rel_height=0.9)
        properties['peaks'] = peaks
        
        if np.nanmean(x_fft) < (np.nanmean(x)- np.nanstd(x_fft)):
            properties['widths'] = len(x)
        
        df_new = pd.DataFrame(properties)
        df = pd.concat([df,df_new])
        
        if plot==True:
            plt.figure()
            plt.plot(np.arange(1,155)-77, x)
            plt.xlabel('El. Distance to Quench')
            plt.ylabel('Voltage Log-Scale')
            plt.plot(peaks-76, x[peaks], "X",  markersize=10)
            #plt.hlines(y=properties["width_heights"], xmin=properties["left_ips"]-76, xmax=properties["right_ips"]-76, color = "C2")
            
            plt.hlines(y=np.mean(x), xmin=-76, xmax=76, color = "C2", label=f"mean=10^{np.mean(x):.2f} V")
            plt.legend()
            
    return df.to_dict(orient='list')

def get_peak_borders(x_fft_3q_main, plot=False):
    x_fft_3q_main_log =  np.log10(x_fft_3q_main)# log_scale_data(x_fft_3q_main) #
    x_fft_3q_main_log_q = np.nanquantile(x_fft_3q_main_log, 0.95, axis=0)

    #The prominence of a peak measures how much a peak stands out from the surrounding baseline of the signal and is defined as the vertical distance between the peak and its lowest contour line.
    peaks, v_properties = find_peaks(x_fft_3q_main_log_q, width=1, prominence=0.1, rel_height=0.9)
    v_properties['peaks'] = peaks
    h_properties = get_horizontal_peak_widths(x_fft_3q_main_log, peaks, plot=plot)
    
    #print(v_properties)
    if plot==True:
        plt.figure()
        plt.plot(frequency_cut, x_fft_3q_main_log_q)
        plt.plot(frequency_cut[v_properties['peaks']], x_fft_3q_main_log_q[v_properties['peaks']], "X",  markersize=10)
        # Interpolated positions of left and right intersection points of a horizontal line at the respective evaluation height.
        plt.hlines(y=v_properties["width_heights"], xmin=frequency_cut[v_properties['left_ips'].astype(int)], xmax=frequency_cut[v_properties['right_ips'].astype(int)], color = "C1")
        #plt.hlines(y=v_properties["width_heights"], xmin=v_properties["left_ips"], xmax=v_properties["right_ips"], color = "C1")
        plt.xlabel('Frequency / Hz')
        plt.ylabel('Voltage Log-Scale')
        
        #plt.hlines(y=v_properties["width_heights"], xmin=v_properties["left_bases"], xmax=v_properties["right_bases"], color = "C2")
        
    return v_properties, h_properties

v_properties_main, h_properties_main = get_peak_borders(x_fft_3q_main, plot = True)
v_properties_mirror, h_properties_mirror = get_peak_borders(x_fft_3q_mirror)

# %%
main_peak_idxs = v_properties_main['peaks']
mirror_peak_idxs = v_properties_mirror['peaks']

total = np.zeros((2,100, 5))
for i in range(100):
    total[0, i] = np.nanmean(np.nanquantile(x_fft_all[0], i/100,  axis=0)[:,mirror_peak_idxs], axis=0)
    total[1, i] = np.nanmean(np.nanquantile(x_fft_all[1], i/100,  axis=0)[:,mirror_peak_idxs], axis=0)
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-90a81d4f61ea> in <module>
#       4 total = np.zeros((2,100, 5))
#       5 for i in range(100):
# ----> 6     total[0, i] = np.nanmean(np.nanquantile(x_fft_all[0], i/100,  axis=0)[:,mirror_peak_idxs], axis=0)
#       7     total[1, i] = np.nanmean(np.nanquantile(x_fft_all[1], i/100,  axis=0)[:,mirror_peak_idxs], axis=0)
#       8     print(i)
#
# ValueError: could not broadcast input array from shape (4,) into shape (5,)

# %%
x_axis_data = np.arange(len(total[1]))/len(total[1])
plt.figure(figsize=(10,7))
color = ['black','b', 'r', 'g', 'orange']

for k, x in enumerate(v_properties_mirror['peaks']):
    plt.plot(x_axis_data, total[0,:,k], c=color[k])
    plt.plot(x_axis_data, total[1,:,k], '--', c=color[k])
    plt.yscale('log')

    plt.ylabel('Voltage / V')
    plt.xlabel('Quantile')
    label = [[str(j) + ' Hz Main', str(j) + ' Hz Mirror'] for j in frequency_cut[v_properties_mirror['peaks']].astype('int')]
    plt.legend(np.array(label).reshape(-1))

# %%
v_properties_main, h_properties_main = get_peak_borders(x_fft_3q_main)
v_properties_mirror, h_properties_mirror = get_peak_borders(x_fft_3q_mirror)

fig, ax = plt.subplots(2,1, figsize=(10,10))
plot_position_frequency_map(ax[0], x_fft_3q_main, frequency_cut)
ax[0].set_title('MAIN')


plot_position_frequency_map(ax[1], x_fft_3q_mirror, frequency_cut)
ax[1].set_title('MIRROR')

plot_ellipse = False
if plot_ellipse:
    for i, p in enumerate(v_properties_main['width_heights']):
        ax[0].add_patch(Ellipse((h_properties_main['peaks'][i]-77, frequency_cut[v_properties_main['peaks']][i]), 
                                width=h_properties_main['widths'][i], height=v_properties_main['widths'][i],
                             edgecolor='red',
                             facecolor='none',
                             linestyle='--',
                             linewidth=1))

    for i, p in enumerate(v_properties_mirror['width_heights']):
        ax[1].add_patch(Ellipse((h_properties_mirror['peaks'][i]-77, frequency_cut[v_properties_mirror['peaks']][i]), 
                                width=h_properties_mirror['widths'][i], height=v_properties_mirror['widths'][i],
                             edgecolor='red',
                             facecolor='none',
                             linestyle='--',
                             linewidth=1))

plt.tight_layout()
plt.show()

# %% [markdown]
# # Pad data

# %% [markdown]
# # Non-negative components - NMF - full data

# %%
def plot_position_frequency_map(ax, x_fft, frequency, norm=colors.LogNorm(), vmin=1e-5, vmax=1e-2):
    im = ax.imshow(x_fft.T, extent=[1,154, frequency.min(),frequency.max()], vmin=vmin, vmax=vmax, aspect='auto', norm=norm, origin='lower')
    
    ax.set_ylabel('Frequency / Hz')
    plt.tight_layout()
    return im

# %%
max_freq = 360
x_fft_all = dataset_fft.loc[{'event': fpa_identifiers}].data
max_freq_bool = frequency <= max_freq
x_fft_cut = x_fft_all[:,:,max_freq_bool]
frequency_cut = frequency[max_freq_bool]
    
x_fft_scaled = np.nan_to_num(np.array([log_scale_data(X, vmin=1e-5, vmax=1e-2) for X in x_fft_cut]))
data = x_fft_scaled.reshape(-1,np.shape(x_fft_cut)[2])

event_idex = 1
data_plot = (data)[event_idex*154:event_idex*154+154].T 
plt.imshow(data_plot, extent=[-77,77, frequency_cut.min(), frequency_cut.max()], aspect='auto', origin='lower')
plt.show()
plt.hist(data.reshape(-1), bins=100)
plt.show()
#plt.hist((data - data.mean(axis=0, keepdims=True)).reshape(-1), bins=100)
#plt.show()

# %%
n_components = 10
W, H, n_iter = nmf_missing.non_negative_factorization(data, n_components=n_components, init='nndsvd', tol=1e-3, l1_ratio=0.5,  regularization='both', alpha=1)

fig, ax = plt.subplots(figsize = (12,5))
ax.plot(frequency_cut, H.T)#
ax.set_xlabel('Frequency / Hz')
ax.set_ylabel('Value / V')
ax.set_title(f'{n_components} Frequency Components, n_iter {n_iter}')
ax.legend([f"Component {i}" for i in range(n_components)])
ax.set_xlim([frequency_cut.min(),frequency_cut.max()])
ax.grid()

# %%
n_components = 10
W, H, n_iter = nmf_missing.non_negative_factorization(data, n_components=n_components, solver="mu", init='nndsvda', tol=1e-3, l1_ratio=0.5,  regularization='both', alpha=1, ortho_reg=0.1)

fig, ax = plt.subplots(figsize = (12,5))
ax.plot(frequency_cut, H.T)#
ax.set_xlabel('Frequency / Hz')
ax.set_ylabel('Value / V')
ax.set_title(f'{n_components} Frequency Components, n_iter {n_iter}')
ax.legend([f"Component {i}" for i in range(n_components)])
ax.set_xlim([frequency_cut.min(),frequency_cut.max()])
ax.grid()

# %%
event_idex = 30

fig, ax = plt.subplots(2,3, figsize=(20,12))
plot_circuit_frequencies(ax[0,0], x_fft_cut[event_idex], frequency_cut, rb_magnet_metadata_subset)
#ax[0,0].imshow(x_fft_all[event_idex].T)#, cmap=plt.cm.gray)
ax[0,0].set_ylabel('frequency')
ax[0,0].set_xlabel('El. Position')
ax[0,0].set_title(f'original image {event_idex}')

#ax[0,1].plot(base[event_idex,:,0], label="position 0")
#ax[0,1].plot(base[event_idex,:,-2], label="position 30")
#ax[0,1].set_title('true frequency components')

ax[1,0].plot(W[event_idex*154:event_idex*154+154])#, cmap=plt.cm.gray)
ax[1,0].set_ylabel('value')
ax[1,0].set_xlabel('El. Position')
ax[1,0].set_title(f'component weight {event_idex}')
ax[1,0].legend([f"component {i}" for i in range(n_components)])
ax[1,0].set_xlim([0,154])

ax[0,1].plot(H.T,frequency_cut)#, cmap=plt.cm.gray)
ax[0,1].set_ylabel('frequency')
ax[0,1].set_xlabel('value')
ax[0,1].set_title('reconstructed frequency components')
ax[0,1].legend([f"component {i}" for i in range(n_components)])
ax[0,1].set_ylim([frequency_cut.min(),frequency_cut.max()])


x_fft_reconstructed = W[event_idex*154:event_idex*154+154]  @ H #W[event_idex*154:event_idex*154+154]
plot_position_frequency_map(ax[1,1], x_fft_reconstructed, frequency_cut, norm=None, vmin=None, vmax=None)
ax[1,1].set_ylabel('frequency')
ax[1,1].set_xlabel('position')
ax[1,1].set_title(f'reconstructed image {event_idex}')

ax[0,2].set_axis_off()
ax[1,2].set_axis_off()
row = {"a":"b", "c":"d", "c3":"d1", "c5":"d2", "c11":"d3", "c":"d", "c":"d"}
ax[0,2].text(0,1,"Hyperparameters", fontsize="x-large")
i=1
for key, value in row.items():
    ax[0,2].text(0,1-i*0.05,f"{key} = {value}", fontsize="large", va="top")
    i+=1

plt.tight_layout()

# %% [markdown]
# # Summarizing components

# %%
fig, ax = plt.subplots(figsize = (4,3))
plot_position_frequency_map(ax, W[event_idex*154:event_idex*154+154]  @ H, frequency_cut, norm=None, vmin=None, vmax=None)
ax.set_ylabel('Frequency')
ax.set_xlabel('El. Position')
# Out:
# Text(0.5, 6.0, 'El. Position')

# %%
component_indexes = [0, [1,3], [2,4,5,7,8],6, 9]
fig, ax = plt.subplots(5,1, figsize = (4,2*5))

for k, i in enumerate(component_indexes): 
    if isinstance(i, list):
        x_fft_reconstructed = np.zeros_like(x_fft_cut[event_idex])
        for j in i: 
            x_fft_reconstructed += W[event_idex*154:event_idex*154+154, j:j+1]  @ H[j:j+1]       
    else: 
        x_fft_reconstructed = W[event_idex*154:event_idex*154+154, i:i+1]  @ H[i:i+1]
    plot_position_frequency_map(ax[k], x_fft_reconstructed, frequency_cut, norm=None, vmin=None, vmax=None)
    
    if k <4:
        ax[k].set_xticks([])
    else:
        ax[k].set_xlabel('El. Position')
    
plt.tight_layout(pad=0)

# %%
default_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
component_indexes = [0, [1,3], [2,4,5,7,8],6, 9]
fig, ax = plt.subplots(5,1, figsize = (4,2*5))

for k, i in enumerate(component_indexes): 
    if isinstance(i, list):
        W_temp = 0
        for j in i: 
            W_temp += W[event_idex*154:event_idex*154+154, j:j+1]        
    else: 
        W_temp = W[event_idex*154:event_idex*154+154, i:i+1]  
        
    ax[k].plot(W_temp, c=default_colors[k])#
    
    if k <4:
        ax[k].set_xticks([])
    else:
        ax[k].set_xlabel('El. Position')
    #ax[k].set_yticks([])
    ax[k].set_ylabel('Voltage / V')
#plt.setp(ax, ylim=ax[0].get_ylim())
plt.tight_layout(pad=0)

# %%
default_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
component_indexes = [0, [1,3], [2,4,5,7,8],6, 9]
fig, ax = plt.subplots(5,1, figsize = (4,2*5))

for k, i in enumerate(component_indexes): 
    if isinstance(i, list):
        H_temp = 0
        for j in i: 
            H_temp += H[j:j+1]        
    else: 
        H_temp = H[i:i+1] 
        
    ax[k].plot(frequency_cut,H_temp.T, c=default_colors[k])#
    ax[k].set_ylabel('Voltage / V')
    
    if k <4:
        ax[k].set_xticks([])
    else:
        ax[k].set_xlabel('Frequency / Hz')

#plt.setp(ax, ylim=ax[0].get_ylim())
plt.tight_layout(pad=0)

# %%
fig, ax = plt.subplots(figsize = (4,3))
plot_position_frequency_map(ax, x_fft_cut[event_idex], frequency_cut)
ax.set_ylabel('Frequency')
ax.set_xlabel('El. Position')

component_indexes = [0, [1,3], [2,4,5,7,8],6, 9, []]
for i in component_indexes: 
    fig, ax = plt.subplots(figsize = (4,3))
    if isinstance(i, list):
        x_fft_reconstructed = np.zeros_like(x_fft_cut[event_idex])
        for j in i: 
            x_fft_reconstructed += W[event_idex*154:event_idex*154+154, j:j+1]  @ H[j:j+1]       
    else: 
        x_fft_reconstructed = W[event_idex*154:event_idex*154+154, i:i+1]  @ H[i:i+1]
        
    plot_position_frequency_map(ax, x_fft_reconstructed, frequency_cut, norm=None, vmin=None, vmax=None)
    ax.set_ylabel('Frequency')
    ax.set_xlabel('El. Position')

# %%
default_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
event_idex = 30

fig, ax = plt.subplots(n_components, 3, figsize = (15,4*n_components))
for i in range(n_components):
    
    ax[i,0].plot(frequency_cut, H[i], c=default_colors[i])#, cmap=plt.cm.gray)
    ax[i,0].set_xlabel('Frequency \ Hz')
    ax[i,0].set_ylabel('Voltage \ V')
    ax[i,0].set_title(f'Component {i}')
    ax[i,0].set_ylim((0,20))
    
    ax[i,1].plot(W[event_idex*154:event_idex*154+154,i], c=default_colors[i])#, cmap=plt.cm.gray)
    ax[i,1].set_ylabel('Voltage \ V')
    ax[i,1].set_xlabel('El. Position')
    ax[i,1].set_title(f'Vomponent {i} Weight')
    ax[i,1].set_xlim([0,154])
    ax[i,1].set_ylim((0,0.08))

    x_fft_reconstructed = W[event_idex*154:event_idex*154+154, i:i+1]  @ H[i:i+1]
    plot_position_frequency_map(ax[i,2], x_fft_reconstructed, frequency_cut, norm=None, vmin=None, vmax=None)
    ax[i,2].set_ylabel('Frequency')
    ax[i,2].set_xlabel('El. Position')
    ax[i,2].set_title(f'Reconstructed Component {i}')
    
plt.tight_layout()

# %% [markdown]
# # Non-negative components - NMF

# %%
def interpol_image(X):
    
    x_fft_interpol = X
    x_index = np.arange(len(X))
    nan_index = np.isnan(X).all(axis=1)

    if len(x_index[nan_index]) > 0:
        f = interp2d(x_index[~nan_index], frequency_cut, X[~nan_index].T)
        x_fft_interpol[nan_index] = f(x_index[nan_index], frequency_cut).T
    else:
        x_fft_interpol = X
    return x_fft_interpol

# %%
def plot_position_frequency_map_half(ax, x_fft, frequency, norm=colors.LogNorm(), vmin=1e-5, vmax=1e-2):
    im = ax.imshow(x_fft.T, extent=[0,77, frequency.min(),frequency.max()], vmin=vmin, vmax=vmax, aspect='auto', norm=norm, origin='lower')
    
    ax.set_ylabel('Frequency / Hz')
    ax.set_xlabel('El. Distance to Quench')
    
    plt.tight_layout()
    return im

# %%
def get_nmf_components(data, n_components=4):
    estimator = decomposition.NMF(n_components=n_components, init='nndsvda', tol=5e-3)
    estimator.fit(data)
    return estimator.components_

def get_nmf_components_missing_values(data, n_components=4):
    estimator = nmf_missing.NMF(n_components=n_components, tol=5e-5, init='random', solver='mu', max_iter=500, beta_loss='kullback-leibler')
    estimator.fit(data)
    return estimator.components_

# %%
# el pos plot std
x_fft_half = np.zeros((2, len(fpa_identifiers), 77, 116)) *np.nan

for i, fpa_identifier in enumerate(fpa_identifiers): 
    
    first_half = x_fft_all[0, i, :77]
    first_half_mirror = x_fft_all[1, i, :77]
    second_half = x_fft_all[0, i, 77:]
    second_half_mirror = x_fft_all[1, i, 77:]
    
    first_half_not_nan = ~np.isnan(first_half).all(axis=1)
    first_half_mirror_not_nan = ~np.isnan(first_half_mirror).all(axis=1)
    second_half_not_nan = ~np.isnan(second_half).all(axis=1)
    second_half_mirror_not_nan = ~np.isnan(second_half_mirror).all(axis=1)
    
    if sum(first_half_not_nan) > 38:
        # more than half of the values are in first half
        x_fft_half[0, i, :sum(first_half_not_nan)] = first_half[first_half_not_nan][::-1]
        x_fft_half[1, i, :sum(second_half_mirror_not_nan)] = second_half_mirror[second_half_mirror_not_nan]

    else:
        x_fft_half[0, i, :sum(second_half_not_nan)] = second_half[second_half_not_nan]
        x_fft_half[1, i, :sum(first_half_mirror_not_nan)] = first_half_mirror[first_half_mirror_not_nan][::-1]
        
    x_fft_half[0, i] = interpol_image(x_fft_half[0, i])
    x_fft_half[1, i] = interpol_image(x_fft_half[1, i])
        
    if True:
        fig, ax = plt.subplots(1,2, figsize=(8,5))
        plot_position_frequency_map_half(ax[0], x_fft_half[0, i], frequency_cut)
        ax[0].set_title('MAIN')
        ax[1].set_title('MIRROR')
        plot_position_frequency_map_half(ax[1], x_fft_half[1, i], frequency_cut)

        fig, ax = plt.subplots(1,2, figsize=(15,5))
        plot_position_frequency_map(ax[0], x_fft_all[0, i], frequency_cut)
        ax[0].set_title('MAIN')
        ax[1].set_title('MIRROR')
        plot_position_frequency_map(ax[1], x_fft_all[1, i], frequency_cut)

        if i > 10:
            break

# %% [markdown]
# # NMF with interpolated values

# %%
n_components=6
data = np.nan_to_num(np.array([log_scale_data(X) for X in x_fft_half[0]]))
data_shape = np.shape(data)
components_ = get_nmf_components(data.reshape(data_shape[0],-1), n_components=n_components)

# %%
for n in range(n_components):
    fig, ax = plt.subplots(figsize=(5,5))
    ax.set_title(f'component: {n}')
    plot_position_frequency_map_half(ax, components_[n].reshape(data_shape[1:]), frequency_cut, norm=None, vmin=1e-5, vmax=2e-1)

# %% [markdown]
# # NMF with zero padding

# %%
n_components=4
data = np.nan_to_num(np.array([log_scale_data(X) for X in x_fft_all[1]]))
data_shape = np.shape(data)
components_ = get_nmf_components(data.reshape(data_shape[0],-1), n_components=n_components)

for n in range(n_components):
    fig, ax = plt.subplots(figsize=(10,5))
    plot_position_frequency_map(ax, components_[n].reshape(data_shape[1:]), frequency_cut, norm=None)

# %% [markdown]
# # NMF with interpolated values

# %%
event_nr = 2
x_fft_scaled = log_scale_data(x_fft_all[1, event_nr])
fig, ax = plt.subplots(figsize=(10,5))
plot_position_frequency_map(ax, x_fft_all[1, event_nr], frequency, norm=None)

x_fft_interpol = x_fft_scaled
fig, ax = plt.subplots(figsize=(10,5))
plot_position_frequency_map(ax, x_fft_interpol, frequency, norm=None)

# %%
n_components=4
data = np.nan_to_num(np.array([log_scale_data(interpol_image(X)) for X in x_fft_all[1]]))
data_shape = np.shape(data)
components_ = get_nmf_components(data.reshape(data_shape[0],-1), n_components=n_components)

for n in range(n_components):
    fig, ax = plt.subplots(figsize=(10,5))
    plot_position_frequency_map(ax, components_[n].reshape(data_shape[1:]), frequency_cut, norm=None)

# %% [markdown]
# # NMF with nan values

# %%
n_components=4
data = np.nan_to_num(np.array([log_scale_data(X) for X in x_fft_all[1]]))
data_shape = np.shape(data)
components_ = get_nmf_components_missing_values(data.reshape(data_shape[0],-1), n_components=n_components)

for n in range(n_components):
    fig, ax = plt.subplots(figsize=(10,5))
    plot_position_frequency_map(ax, components_[n].reshape(data_shape[1:]), frequency_cut, norm=None)

# %% [markdown]
# # Calculate mean of frequency position map

# %%
# el pos
x_fft_all = np.zeros((len(fpa_identifiers),)+ x_fft_centered.shape)

for i, fpa_identifier in enumerate(fpa_identifiers): 
    x_fft = dataset_fft.loc[{'event': fpa_identifier}].data
    x_fft_all[i], frequency_cut = preprocess_event(x_fft, frequency, fpa_identifier, max_freq=360)
x_fft_mean = np.nanmean(x_fft_all, axis=0)

fig, ax = plt.subplots(figsize=(10,5))
plot_circuit_frequencies(ax, x_fft_mean, frequency, rb_magnet_metadata_subset)

# %%
frequency_cut[v_properties_main['peaks']], frequency_cut[v_properties_mirror['peaks']]

# %%
# phys pos
phys_pos_index = rb_magnet_metadata_subset['#Electric_circuit'].values 

frequency = fftfreq(len(x_time[0]), dt)[:len(x_time[0])//2] 
x_fft_all_phys_pos = np.zeros((len(fpa_identifiers),)+ x_fft_centered.shape)

for i, fpa_identifier in enumerate(fpa_identifiers): 
    x_fft = dataset_fft.loc[{'event': fpa_identifier}].data
        
    x_fft_phys_pos = x_fft[phys_pos_index-1]
    x_fft_all_phys_pos[i], _ = preprocess_event_phys_pos(x_fft_phys_pos, frequency, fpa_identifier, max_freq=360)
x_fft_mean_phys_pos = np.nanmean(x_fft_all_phys_pos, axis=0)

x_fft_mean_phys_pos[154] = 0
fig, ax = plt.subplots(figsize=(10,5))
plot_circuit_frequencies(ax, x_fft_mean_phys_pos, frequency, rb_magnet_metadata_subset)

# %% [markdown]
# # Find Oszillation margins

# %%
v_properties, h_properties

# %%
h_properties

# %%
h_properties_main['peaks']

# %%
def get_meanfilt_window(signal, distance_to_border):
    frequency_ranges = np.arange(len(signal)-1)
    magnet_ranges = np.arange(len(signal[0]))
    
    signal_filt = pd.DataFrame(signal.T).rolling(5, center=True).mean().values.reshape(-1,distance_to_border).T # shape: (distance_to_border, frequency_ranges)
    signal_filt[signal_filt<0.00001] = 0
    signal_diff = np.diff(signal_filt, axis=0) # shape: (distance_to_border-1, frequency_ranges)


    oszil_stop = [frequency_ranges[(signal_diff[:,i] > 0)]  for i in magnet_ranges]
    oszil_stop = np.array([o[0] if o[:1] else 0 for o in oszil_stop])
    oszil_stop_filt = pd.DataFrame(oszil_stop).rolling(3, center=True).mean().values
    return oszil_stop_filt

def get_oszil_ranges(x_fft, quench_pos):
    oszil_stop_left = get_meanfilt_window(x_fft[:int(quench_pos)][::-1], int(quench_pos))
    oszil_stop_right = get_meanfilt_window(x_fft[int(quench_pos):], 154 - int(quench_pos))
    return oszil_stop_left, oszil_stop_right

# %%
mp3_fpa_df_subset_fast = mp3_fpa_df_subset[mp3_fpa_df_subset['Delta_t(iQPS-PIC)'] / 1000 < 1]

# phys pos
plt.figure(figsize=(15,10))
quench_phys_pos = mp3_fpa_df_subset_fast['phys_position'].values
quench_phy_distance_to_border = [(x, 154-x) for x in quench_phys_pos]

phys_posindex = rb_magnet_metadata_subset['#Electric_circuit'].values 
x_fft_phys_pos = x_fft[phys_posindex-1]

quench_pos = quench_phys_pos[0]
oszil_stop_filt = get_oszil_ranges(x_fft_phys_pos, quench_pos)
plt.imshow(x_fft_phys_pos.T, extent=[1,154, frequency.min(),frequency.max()], vmin=0.0001, vmax=1, aspect='auto', norm=colors.LogNorm(), origin='lower')

plt.plot(oszil_stop_filt[1] + quench_pos, np.linspace(frequency.min(),frequency.max(),len(oszil_stop_filt[1] )), c='r')
plt.plot(quench_pos - oszil_stop_filt[0] , np.linspace(frequency.min(),frequency.max(),len(oszil_stop_filt[1] )), c='r')

# %%
# el pos
plt.figure(figsize=(15,10))
quench_el_pos = mp3_fpa_df_subset_fast['#Electric_circuit'].values
quench_phy_distance_to_border = [(x, 154-x) for x in quench_el_pos]

quench_pos = quench_el_pos[0]
oszil_stop_filt = get_oszil_ranges(x_fft, quench_pos)
plt.imshow(x_fft.T, extent=[1,154, frequency.min(),frequency.max()], vmin=0.0001, vmax=1, aspect='auto', norm=colors.LogNorm(), origin='lower')
plt.plot(oszil_stop_filt[1] + quench_pos, np.linspace(frequency.min(),frequency.max(),len(oszil_stop_filt[1] )), c='r')
plt.plot(quench_pos - oszil_stop_filt[0] , np.linspace(frequency.min(),frequency.max(),len(oszil_stop_filt[1] )), c='r')

# %%
#quench_pos = 146 #137
#signal = x_fft[:int(quench_pos)][::-1]
quench_pos = 137
signal = x_fft_phys_pos[int(quench_pos):]
distance_to_border = 154-int(quench_pos)

frequency_ranges = np.arange(len(signal)-1)
magnet_ranges = np.arange(len(signal[0]))

#oszil_stop_filt = get_meanfilt_window(signal, distance_to_border)
signal_filt = pd.DataFrame(signal.T).rolling(5, center=True).mean().values.reshape(-1,distance_to_border).T # shape: (distance_to_border, frequency_ranges)
signal_filt[signal_filt<0.0001] = 0
signal_diff = np.diff(signal_filt, axis=0) # shape: (distance_to_border-1, frequency_ranges)

oszil_stop = [frequency_ranges[(signal_diff[:,i] >= 0)]  for i in magnet_ranges]
oszil_stop = np.array([o[0] if o[:1] else 0 for o in oszil_stop])
oszil_stop_filt = pd.DataFrame(oszil_stop).rolling(3, center=True).mean().values

plt.title(np.shape(signal.T))
plt.imshow(signal.T, extent=[0,distance_to_border, frequency.min(),frequency.max()], vmin=0.0001, vmax=1, aspect='auto', norm=colors.LogNorm(), origin='lower')
plt.plot(oszil_stop_filt, np.linspace(frequency.min(),frequency.max(),len(oszil_stop)), c='r')

plt.figure()
plt.title(np.shape(signal_filt.T))
plt.imshow(signal_filt.T, extent=[1,distance_to_border, frequency.min(),frequency.max()], vmin=0.0001, vmax=1, aspect='auto', norm=colors.LogNorm(), origin='lower')

plt.figure()
plt.title(np.shape(signal_diff.T))
plt.imshow(-signal_diff.T, extent=[0,distance_to_border, frequency.min(),frequency.max()], vmin=0.0001, vmax=1, aspect='auto', norm=colors.LogNorm(), origin='lower')
plt.plot(oszil_stop_filt, np.linspace(frequency.min(),frequency.max(),len(oszil_stop)), c='r')

# get value of first
