# %% [markdown]
# # Import libraries

# %%
import sys
from pathlib import Path
sys.path.insert(0,'..')

# %%
import pandas as pd

from data.processed.MP3_context.process_MP3_excel import process_mp3_excel
from data.processed.RB_position_context.generate_RB_position_context import generate_RB_position_context
from data.processed.RB_snapshot_context.generate_RB_snapshot_context import generate_RB_snapshot_context
from data.processed.position_mapping.generate_position_mapping import generate_position_mapping

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Process MP3 excel file

# %%
data_dir = Path("../data/raw/MP3_context/")
output_dir = Path("../data/processed/MP3_context/")
file_name = "RB_TC_extract_2023_03_13"
file_name = "RB_TC_extract_2023_11_17"

process_mp3_excel(input_dir=data_dir, output_dir=output_dir, mp3_file_name=file_name)

# %%
df_mp3 = pd.read_csv(output_dir / (file_name + "_processed.csv"), index_col=False)
df_mp3
# Out:
#       Unnamed: 0 Circuit Name Circuit Family          Period  Date (FGC)  \
# 0              2       RB.A78             RB        HWC 2007  2007-06-27
# 1              3       RB.A78             RB        HWC 2007  2007-06-27
# 2              4       RB.A78             RB        HWC 2007  2007-06-27
# 3              5       RB.A45             RB        HWC 2007  2007-12-18
# 4              6       RB.A45             RB        HWC 2007  2007-12-18
# ...          ...          ...            ...             ...         ...
# 4884        4887       RB.A23             RB  Operation 2023  2023-10-19
# 4885        4888       RB.A81             RB  Operation 2023  2023-10-30
# 4886        4889       RB.A81             RB  Operation 2023  2023-10-30
# 4887        4890       RB.A81             RB  Operation 2023  2023-10-30
# 4888        4891       RB.A81             RB  Operation 2023  2023-10-30
#
#            Time (FGC)       FPA Reason               Timestamp_PIC  \
# 0            07:40:31  Heater-provoked                         NaN
# 1            11:13:10  Heater-provoked                         NaN
# 2            12:16:37  Heater-provoked                         NaN
# 3            10:10:35  Heater-provoked                         NaN
# 4            18:19:06  Heater-provoked                         NaN
# ...               ...              ...                         ...
# 4884  11:27:08.140000         QPS trip  2023-10-19 11:27:08.117000
# 4885  03:49:30.640000    Magnet quench  2023-10-30 03:49:30.615000
# 4886  03:49:30.640000    Magnet quench  2023-10-30 03:49:30.615000
# 4887  03:49:30.640000    Magnet quench  2023-10-30 03:49:30.615000
# 4888  03:49:30.640000    Magnet quench  2023-10-30 03:49:30.615000
#
#      Delta_t(FGC-PIC)  Delta_t(EE_even-PIC)  ... dI_Q_Acc  dI_Q_LHC  \
# 0                 NaN                   NaN  ...        -       NaN
# 1                 NaN                   NaN  ...        -       NaN
# 2                 NaN                   NaN  ...        -       NaN
# 3                 NaN                   NaN  ...        -       NaN
# 4                 NaN                   NaN  ...        -       NaN
# ...               ...                   ...  ...      ...       ...
# 4884               23                 598.0  ...        -       NaN
# 4885               25                 593.0  ...        -       NaN
# 4886               25                 593.0  ...        -       NaN
# 4887               25                 593.0  ...        -       NaN
# 4888               25                 593.0  ...        -       NaN
#
#                                                 Comment  \
# 0                                      No diode opening
# 1                                                   NaN
# 2                       Measurement cards dumps swapped
# 3                                      No diode opening
# 4                                    QH test during HWC
# ...                                                 ...
# 4884  nQPS reset at nominal current; nQPS signals ar...
# 4885                        MD Beam induced Quench Test
# 4886                        MD Beam induced Quench Test
# 4887                        MD Beam induced Quench Test
# 4888                        MD Beam induced Quench Test
#
#       Analysis performed by  lhcsmapi version  lhcsm notebook version  \
# 0                       NaN               NaN                     NaN
# 1                       NaN               NaN                     NaN
# 2                       NaN               NaN                     NaN
# 3                       NaN               NaN                     NaN
# 4                       NaN               NaN                     NaN
# ...                     ...               ...                     ...
# 4884                  zinur             1.6.7                  1.5.66
# 4885                  zinur             1.6.7                   1.6.5
# 4886                  zinur             1.6.7                   1.6.5
# 4887                  zinur             1.6.7                   1.6.5
# 4888                  zinur             1.6.7                   1.6.5
#
#      Unnamed: 46 Unnamed: 47  timestamp_fgc                 fpa_identifier
# 0            NaN         NaN            NaN                            NaN
# 1            NaN         NaN            NaN                            NaN
# 2            NaN         NaN            NaN                            NaN
# 3            NaN         NaN            NaN                            NaN
# 4            NaN         NaN            NaN                            NaN
# ...          ...         ...            ...                            ...
# 4884         NaN         NaN   1.697708e+18  RB_RB.A23_1697707628140000000
# 4885         NaN         NaN   1.698634e+18  RB_RB.A81_1698634170640000000
# 4886         NaN         NaN   1.698634e+18  RB_RB.A81_1698634170640000000
# 4887         NaN         NaN   1.698634e+18  RB_RB.A81_1698634170640000000
# 4888         NaN         NaN   1.698634e+18  RB_RB.A81_1698634170640000000
#
# [4889 rows x 51 columns]

# %% [markdown]
# # Process Snapshot file

# %%
data_dir = Path("../data/raw/MP3_context/")
output_dir = Path("../data/processed/RB_snapshot_context/")
file_name = "RB_snapshot_context"

generate_RB_snapshot_context(input_dir=data_dir, output_dir=output_dir, file_name=file_name)

# %%
df_snapshots = pd.read_csv(output_dir / (file_name + ".csv"), index_col=False)
df_snapshots
# Out:
#     Unnamed: 0 Circuit Name           case        snapshot_date  \
# 0            0       RB.A12      2kA@10A/s  20210929-171841.860
# 1            1       RB.A23      2kA@10A/s  20211007-172946.940
# 2            2       RB.A34      2kA@10A/s  20210917-165956.200
# 3            3       RB.A45      2kA@10A/s  20210714-172843.720
# 4            4       RB.A56      2kA@10A/s  20210715-172329.660
# ..         ...          ...            ...                  ...
# 59          59       RB.A45  11kA flat top  20220314-180432.060
# 60          60       RB.A56  11kA flat top  20220314-180456.120
# 61          61       RB.A67  11kA flat top  20220314-180525.040
# 62          62       RB.A78  11kA flat top  20220311-170212.220
# 63          63       RB.A81  11kA flat top  20220324-113328.260
#
#                   fgc_datetime Circuit Family        timestamp_fgc  \
# 0   2021-09-29 17:18:41.860000             RB  1632928721860000000
# 1   2021-10-07 17:29:46.940000             RB  1633620586940000000
# 2   2021-09-17 16:59:56.200000             RB  1631890796200000000
# 3   2021-07-14 17:28:43.720000             RB  1626276523720000000
# 4   2021-07-15 17:23:29.660000             RB  1626362609660000000
# ..                         ...            ...                  ...
# 59  2022-03-14 18:04:32.060000             RB  1647277472060000000
# 60  2022-03-14 18:04:56.120000             RB  1647277496120000000
# 61  2022-03-14 18:05:25.040000             RB  1647277525040000000
# 62  2022-03-11 17:02:12.220000             RB  1647014532220000000
# 63  2022-03-24 11:33:28.260000             RB  1648118008260000000
#
#                    fpa_identifier
# 0   RB_RB.A12_1632928721860000000
# 1   RB_RB.A23_1633620586940000000
# 2   RB_RB.A34_1631890796200000000
# 3   RB_RB.A45_1626276523720000000
# 4   RB_RB.A56_1626362609660000000
# ..                            ...
# 59  RB_RB.A45_1647277472060000000
# 60  RB_RB.A56_1647277496120000000
# 61  RB_RB.A67_1647277525040000000
# 62  RB_RB.A78_1647014532220000000
# 63  RB_RB.A81_1648118008260000000
#
# [64 rows x 8 columns]

# %% [markdown]
# # Process RB Position Context

# %%
year = 2021
data_dir = Path("../data/raw")
RB_LayoutDetails_path = data_dir / "SIGMON_context/RB_LayoutDetails.csv"
nQPS_RB_busBarProtectionDetails_path = data_dir / "SIGMON_context/nQPS_RB_busBarProtectionDetails.csv"
RB_Beamscreen_Resistances_path = data_dir / "MB_feature_analysis/RB_Beamscreen_Resistances.csv"
RB_Magnet_metadata_path = data_dir / "MP3_context/RB_TC_extract_2023_03_13.xlsx"
output_dir = Path("../data/processed/RB_position_context/")
generate_RB_position_context(year=year,
                             RB_LayoutDetails_path=RB_LayoutDetails_path,
                             nQPS_RB_busBarProtectionDetails_path=nQPS_RB_busBarProtectionDetails_path,
                             RB_Beamscreen_Resistances_path=RB_Beamscreen_Resistances_path,
                             RB_Magnet_metadata_path=RB_Magnet_metadata_path,
                             output_dir=output_dir)

# %%
df_position_context = pd.read_csv(output_dir / "RB_position_context.csv", index_col=False)
df_position_context
# Out:
#      Circuit    Magnet    Position B1_aperture Diode_type Correctors EE place  \
# 0     RB.A12   MB.A8R1    276.7340         EXT          R          A     EVEN
# 1     RB.A12   MB.B8R1    292.3940         EXT          R          B      ODD
# 2     RB.A12   MB.A9R1    315.7990         EXT          R          A     EVEN
# 3     RB.A12   MB.B9R1    331.4590         EXT          R          B      ODD
# 4     RB.A12  MB.A10R1    356.2640         EXT          R          A     EVEN
# ...      ...       ...         ...         ...        ...        ...      ...
# 1227  RB.A81  MB.A10L1  26302.6192         INT          L          B      ODD
# 1228  RB.A81   MB.B9L1  26327.4242         INT          L          A     EVEN
# 1229  RB.A81   MB.A9L1  26343.0842         INT          L          B      ODD
# 1230  RB.A81   MB.B8L1  26366.4892         INT          L          A     EVEN
# 1231  RB.A81   MB.A8L1  26382.1492         INT          L          B      ODD
#
#       #Electric_EE  #Electric_circuit    Cryostat  ...   age Manufacturer  \
# 0                1                 78   LBARE.8R1  ...  14.0          3.0
# 1               77                 77   LBBRF.8R1  ...  14.0          2.0
# 2                2                 79   LBARE.9R1  ...  14.0          2.0
# 3               76                 76   LBBRG.9R1  ...  14.0          2.0
# 4                3                 80  LBARE.10R1  ...  14.0          1.0
# ...            ...                ...         ...  ...   ...          ...
# 1227            75                 75  LBBLG.10L1  ...  14.0          3.0
# 1228             2                 79   LBALE.9L1  ...  14.0          1.0
# 1229            76                 76   LBBLF.9L1  ...  14.0          2.0
# 1230             1                 78   LBALE.8L1  ...  14.0          3.0
# 1231            77                 77   LBBLQ.8L1  ...  14.0          1.0
#
#      Inner cable type Outer cable type I_Q_SM18  Renamed short magnet ID  \
# 0                 01B             02B8  11488.0                      NaN
# 1                 01E             02C0  10622.0                      NaN
# 2                 01E             02C9  12427.0                      NaN
# 3                 01E             02C9  11155.0                      NaN
# 4                 01E             02B8  11782.0                      NaN
# ...               ...              ...      ...                      ...
# 1227              01B              02G  12645.0                      NaN
# 1228              01B             02B5  12379.0                      NaN
# 1229              01B              02K  11757.0                      NaN
# 1230              01B              02G  11656.0                      NaN
# 1231              01B             02B5  12506.0                      NaN
#
#       MTF Status  Magnet_construction_order QPS Crate Number  Cryostat Number
# 0            NaN                        288                0                0
# 1            NaN                        256                0                1
# 2            NaN                        330                1                0
# 3            NaN                        319                2                1
# 4            NaN                        296                0                0
# ...          ...                        ...              ...              ...
# 1227         NaN                        123                1                1
# 1228         NaN                         62                1                0
# 1229         NaN                         61                2                1
# 1230         NaN                        172                0                0
# 1231         NaN                        148                0                1
#
# [1232 rows x 41 columns]

# %% [markdown]
# # Generate map of different positions in RB circuit (e.g. El. Position)

# %%
data_dir = Path("../data/processed/RB_position_context/")
file_name = "RB_position_context"

generate_position_mapping(input_dir=data_dir, output_dir=data_dir, file_name=file_name)

# %%
df_position_mapping = pd.read_csv(data_dir / (file_name + ".csv"), index_col=False)
df_position_mapping
# Out:
#      Circuit    Magnet    Position B1_aperture Diode_type Correctors EE place  \
# 0     RB.A12   MB.A8R1    276.7340         EXT          R          A     EVEN
# 1     RB.A12   MB.B8R1    292.3940         EXT          R          B      ODD
# 2     RB.A12   MB.A9R1    315.7990         EXT          R          A     EVEN
# 3     RB.A12   MB.B9R1    331.4590         EXT          R          B      ODD
# 4     RB.A12  MB.A10R1    356.2640         EXT          R          A     EVEN
# ...      ...       ...         ...         ...        ...        ...      ...
# 1227  RB.A81  MB.A10L1  26302.6192         INT          L          B      ODD
# 1228  RB.A81   MB.B9L1  26327.4242         INT          L          A     EVEN
# 1229  RB.A81   MB.A9L1  26343.0842         INT          L          B      ODD
# 1230  RB.A81   MB.B8L1  26366.4892         INT          L          A     EVEN
# 1231  RB.A81   MB.A8L1  26382.1492         INT          L          B      ODD
#
#       #Electric_EE  #Electric_circuit    Cryostat  ...   age Manufacturer  \
# 0                1                 78   LBARE.8R1  ...  14.0          3.0
# 1               77                 77   LBBRF.8R1  ...  14.0          2.0
# 2                2                 79   LBARE.9R1  ...  14.0          2.0
# 3               76                 76   LBBRG.9R1  ...  14.0          2.0
# 4                3                 80  LBARE.10R1  ...  14.0          1.0
# ...            ...                ...         ...  ...   ...          ...
# 1227            75                 75  LBBLG.10L1  ...  14.0          3.0
# 1228             2                 79   LBALE.9L1  ...  14.0          1.0
# 1229            76                 76   LBBLF.9L1  ...  14.0          2.0
# 1230             1                 78   LBALE.8L1  ...  14.0          3.0
# 1231            77                 77   LBBLQ.8L1  ...  14.0          1.0
#
#      Inner cable type Outer cable type I_Q_SM18  Renamed short magnet ID  \
# 0                 01B             02B8  11488.0                      NaN
# 1                 01E             02C0  10622.0                      NaN
# 2                 01E             02C9  12427.0                      NaN
# 3                 01E             02C9  11155.0                      NaN
# 4                 01E             02B8  11782.0                      NaN
# ...               ...              ...      ...                      ...
# 1227              01B              02G  12645.0                      NaN
# 1228              01B             02B5  12379.0                      NaN
# 1229              01B              02K  11757.0                      NaN
# 1230              01B              02G  11656.0                      NaN
# 1231              01B             02B5  12506.0                      NaN
#
#       MTF Status  Magnet_construction_order QPS Crate Number  Cryostat Number
# 0            NaN                        288                0                0
# 1            NaN                        256                0                1
# 2            NaN                        330                1                0
# 3            NaN                        319                2                1
# 4            NaN                        296                0                0
# ...          ...                        ...              ...              ...
# 1227         NaN                        123                1                1
# 1228         NaN                         62                1                0
# 1229         NaN                         61                2                1
# 1230         NaN                        172                0                0
# 1231         NaN                        148                0                1
#
# [1232 rows x 41 columns]
